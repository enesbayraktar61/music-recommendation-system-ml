# %% [markdown]
# <h1 style="text-align: center;">Music Recommendation System</h1>

# %% [markdown]
# The goal of this project is to build a music recommendation system that suggests similar songs based on audio features.

# %% [markdown]
# Import Libraries and Load Dataset

# %%
#import libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %% [markdown]
# EDA - Exploratory Data Analysis

# %%
df.shape
# Out:
# (114000, 21)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %% [markdown]
# Preprocessing

# %%
df = df[[
    "track_name",
    "artists",
    "track_genre",
    "danceability",
    "energy",
    "loudness",
    "tempo",
    "valence"
]]

df.head()
# Out:
#                    track_name                 artists track_genre  \
# 0                      Comedy             Gen Hoshino    acoustic
# 1            Ghost - Acoustic            Ben Woodward    acoustic
# 2              To Begin Again  Ingrid Michaelson;ZAYN    acoustic
# 3  Can't Help Falling In Love            Kina Grannis    acoustic
# 4                     Hold On        Chord Overstreet    acoustic
#
#    danceability  energy  loudness    tempo  valence
# 0         0.676  0.4610    -6.746   87.917    0.715
# 1         0.420  0.1660   -17.235   77.489    0.267
# 2         0.438  0.3590    -9.734   76.332    0.120
# 3         0.266  0.0596   -18.515  181.740    0.143
# 4         0.618  0.4430    -9.681  119.949    0.167

# %%
df.isnull().sum()
# Out:
# track_name      1
# artists         1
# track_genre     0
# danceability    0
# energy          0
# loudness        0
# tempo           0
# valence         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(subset=["track_name", "artists"], inplace=True)

df.shape
# Out:
# (81343, 8)

# %% [markdown]
# Modeling

# %%
features = df[[
    "danceability",
    "energy",
    "loudness",
    "tempo",
    "valence"
]]

features.head()
# Out:
#    danceability  energy  loudness    tempo  valence
# 0         0.676  0.4610    -6.746   87.917    0.715
# 1         0.420  0.1660   -17.235   77.489    0.267
# 2         0.438  0.3590    -9.734   76.332    0.120
# 3         0.266  0.0596   -18.515  181.740    0.143
# 4         0.618  0.4430    -9.681  119.949    0.167

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend(song):
    index = df[df["track_name"] == song].index[0]

    distances = cosine_similarity(
        [scaled_features[index]],
        scaled_features
    )[0]

    songs_list = sorted(
        list(enumerate(distances)),
        reverse=True,
        key=lambda x: x[1]
    )[1:6]

    for i in songs_list:
        print(df.iloc[i[0]].track_name, "-", df.iloc[i[0]].artists)

# %%
recommend("Blinding Lights")
# Out:
# Overwhelm - Alphaxone
# Remembering You - Tony O'Connor
# Imipramine (Pt.1) - PERMEATE
# Autumn (Solo Piano) - Ryan Stewart
# Asmr: Big Air Conditioner - ASMR HD

# %% [markdown]
# The music recommendation system was successfully built using feature-based similarity techniques.
#
# By analyzing numerical audio features such as danceability, energy, loudness, tempo, and valence, we created a recommendation engine capable of suggesting similar songs.
#
# This project demonstrates how similarity-based approaches can be effectively applied to large-scale music datasets without requiring user interaction data.

# %% [markdown]
# Saving

# %%
import pickle

pickle.dump(df, open("music_df.pkl", "wb"))
pickle.dump(scaled_features, open("music_features.pkl", "wb"))

# %%
import os
os.listdir()
# Out:
# ['.config', 'music_df.pkl', 'music_features.pkl', 'dataset.csv', 'sample_data']
